# %% [markdown]
# #  NIFTI_NORDIC in Nipype
#
# __Author:__ Moni Dörig

# %% [markdown]
# ### References:
#
# __NORDIC:__
# - Vizioli, L., Moeller, S., Dowdle, L. et al. Lowering the thermal noise barrier in functional brain mapping with magnetic resonance imaging. Nat Commun 12, 5181 (2021). https://doi.org/10.1038/s41467-021-25431-8
# - [Code on GitHub supporting the publication](https://github.com/SteenMoeller/NORDIC_Raw)
#
# __Opensource Data from OpenNeuro:__
# - Javier Gonzalez-Castilloa and Colin W. Hoy and Daniel A. Handwerker and Vinai Roopchansingh and Souheil J. Inati and Ziad S. Saad and Robert W. Cox and Peter A. Bandettini (2023). Large Single-Subject Functional MRI Datasets at 7T. OpenNeuro. [Dataset] doi: [10.18112/openneuro.ds001555.v1.0.1](https://openneuro.org/datasets/ds001555/versions/1.0.1)

# %%
import lmod
await lmod.purge(force=True)
await lmod.load('matlab/2022a')
await lmod.load('afni/23.3.02')
await lmod.load('fsl/6.0.7.4')
await lmod.list()
# Out:
# ['matlab/2022a', 'afni/23.3.02', 'fsl/6.0.7.4']

# %%
from nipype import Node, Function, Workflow
from nipype.interfaces import afni
from nipype.interfaces.fsl import BET, ApplyMask
from nipype.interfaces.io import DataSink, SelectFiles, File
from nipype.interfaces.utility import IdentityInterface, Function
from nipype.interfaces.base import (CommandLine, traits, TraitedSpec,
                                    BaseInterface, BaseInterfaceInputSpec, File)
from nipype.algorithms.confounds import TSNR
from scipy.io import savemat
import os
import sys

# %% [markdown]
# ### Download data from OpenNeuro

# %%
# %%capture
# Download 1 subject, don't display output
PATTERN = "sub-001/ses-01"

# !datalad install https://github.com/OpenNeuroDatasets/ds001555.git
# !cd ds001555 && datalad get $PATTERN

# %%
# !cd ds001555/sub-001/ses-01 && tree -L 4
# Out:
# .
# ├── anat
# │   ├── sub-001_ses-01_acq-MPRAGE_run-001_T1w.json
# │   ├── sub-001_ses-01_acq-MPRAGE_run-001_T1w.nii.gz -> ../../../.git/annex/objects/FG/jG/MD5E-s11361709--21046e99e714dbe42ab2fafbea250db8.nii.gz/MD5E-s11361709--21046e99e714dbe42ab2fafbea250db8.nii.gz
# │   ├── sub-001_ses-01_run-001_PD.json
# │   └── sub-001_ses-01_run-001_PD.nii.gz -> ../../../.git/annex/objects/z7/Pp/MD5E-s11969134--76c8adafe414fdd1a0be886cb6917e6b.nii.gz/MD5E-s11969134--76c8adafe414fdd1a0be886cb6917e6b.nii.gz
# ├── func
# │   ├── sub-001_ses-01_task-HalfFovNoTask_run-003_bold.json
# │   ├── sub-001_ses-01_task-HalfFovNoTask_run-003_bold.nii.gz -> ../../../.git/annex/objects/Mm/44/MD5E-s117000078--ec792152dff29c551f1f567c7e0fba34.nii.gz/MD5E-s117000078--ec792152dff29c551f1f567c7e0fba34.nii.gz
# │   ├── sub-001_ses-01_task-HalfFovNoTask_run-004_bold.json
# │   ├── sub-001_ses-01_task-HalfFovNoTask_run-004_bold.nii.gz -> ../../../.git/annex/objects/G3/GK/MD5E-s117070442--ba4595bcc7e8f34a169f171a4e33a5d7.nii.gz/MD5E-s117070442--ba4595bcc7e8f34a169f171a4e33a5d7.nii.gz
# │   ├── sub-001_ses-01_task-HalfFovNoTask_run-006_bold.json
# │   ├── sub-001_ses-01_task-HalfFovNoTask_run-006_bold.nii.gz -> ../../../.git/annex/objects/GP/g9/MD5E-s117020424--a754684d8afe0ec128e6d75f679b5bd2.nii.gz/MD5E-s117020424--a754684d8afe0ec128e6d75f679b5bd2.nii.gz
# │   ├── sub-001_ses-01_task-HalfFovNoTask_run-007_bold.json
# │   ├── sub-001_ses-01_task-HalfFovNoTask_run-007_bold.nii.gz -> ../../../.git/annex/objects/zQ/vX/MD5E-s117117262--74f8ee93de0e7de42f27a5a5d147b1a2.nii.gz/MD5E-s117117262--74f8ee93de0e7de42f27a5a5d147b1a2.nii.gz
# │   ├── sub-001_ses-01_task-HalfFovNoTask_run-011_bold.json
# │   └── sub-001_ses-01_task-HalfFovNoTask_run-011_bold.nii.gz -> ../../../.git/annex/objects/4x/Vz/MD5E-s117125158--d6799e63b134d605296ec54f3459b3c0.nii.gz/MD5E-s117125158--d6799e63b134d605296ec54f3459b3c0.nii.gz
# └── sub-001_ses-01_scans.tsv
#
# 2 directories, 15 files

# %%
#define directory with data
data_dir = os.path.abspath(os.path.join('.', 'ds001555'))

# %%
os.path.abspath('.')
# Out:
# '/mnt/neurodesktop-storage/Clean_notebooks'

# %% [markdown]
# ### Nipype Interface for NIFTI_NORDIC Matlab Script

# %%
# Add the scripts directory to sys.path (NIFIT_NORDIC_nipype.m and NIFTI_NORDIC_interface.py)
scripts_dir = os.path.abspath('.')

if scripts_dir not in sys.path:
    sys.path.append(scripts_dir)

# %%
#import NiftiNordic class to wrap matlab script
from NIFTI_NORDIC_interface import NiftiNordic

# %%
NiftiNordic.help()
# Out:
# Inputs::
#
#         [Mandatory]
#         additional_path: (a string)
#                 Additional path to be added with addpath in MATLAB
#         fn_magn_in: (a string or os.PathLike object referring to an existing
#                   file)
#                 Input magnitude file
#         fn_phase_in: (a string or os.PathLike object referring to an existing
#                   file)
#                 Input phase file
#         fn_out: (a string)
#                 Output prefix or suffix
#
#         [Optional]
#         ARG: (a string or os.PathLike object referring to an existing file)
#                 Path to MATLAB struct file representing input parameters
#
# Outputs::
#
#         output_file: (a pathlike object or string representing an existing
#                   file or None)
#                 Denoised nii file
#         add_info_file: (a pathlike object or string representing an existing
#                   file or None)
#                 Optional output file for additional info
#         complex_phase_file: (a pathlike object or string representing an
#                   existing file or None)
#                 Optional output file - saves phase in similar format as input phase
#         complex_magn_file: (a pathlike object or string representing an
#                   existing file or None)
#                 Optional output file - saves magn in similar format as input magn
#         gfactor_map_file: (a pathlike object or string representing an
#                   existing file or None)
#                 Optional output file for gfactor map
#         residual_mat_file: (a pathlike object or string representing an
#                   existing file or None)
#                 Optional output file for NORDIC residuals

# %% [markdown]
# ### Initialize workflow and get funcitonal and anatomical data

# %%
# Create a workflow
#where to store workflow/working directories
experiment_dir = os.path.abspath(os.path.join('.', 'NORDIC_output'))

workflow = Workflow(name='workflow_nordic', base_dir=experiment_dir)
workflow.config["execution"]["crashfile_format"] = "txt"

#functional and anatomical data
fn_magn_in = os.path.join(data_dir, 'sub-001/ses-01/func/sub-001_ses-01_task-HalfFovNoTask_run-003_bold.nii.gz')
anat = os.path.join(data_dir, 'sub-001/ses-01/anat/sub-001_ses-01_acq-MPRAGE_run-001_T1w.nii.gz')

# %% [markdown]
# ### Get mask of anatomical image

# %%
os.environ["FSLOUTPUTTYPE"]="NIFTI_GZ"

# %%
bet = Node(BET(), name='bet')
bet.inputs.in_file = anat 
bet.inputs.mask = True  
bet.inputs.frac = 0.65
bet.inputs.output_type = 'NIFTI_GZ'

# %% [markdown]
# ### Motion correction of raw data

# %%
volreg_raw = Node(afni.Volreg(interp='Fourier', outputtype = 'NIFTI_GZ'), 
                 name='volreg_raw')

volreg_raw.inputs.in_file = fn_magn_in

# %% [markdown]
# ### Resample anatomical mask to functional image

# %%
#resample anat mask to func dimension and resolution
def resample_mask(in_file, wb_mask):
    
    #get binary masks of functional run
    import os
    import nibabel as nib
    from nilearn.image import resample_to_img

    base_name = os.path.basename(in_file) 
    file_without_ext = base_name.rsplit('.', 2)[0] #split nii.gz
    new_file = file_without_ext + '_func_mask.nii.gz'
    file_path = os.path.join(os.getcwd(), new_file)

    mask_img = resample_to_img(source_img=nib.load(wb_mask), target_img=nib.load(in_file), interpolation='nearest')
    nib.save(mask_img, file_path)

    return file_path


get_fmri_mask = Node(Function(input_names=['in_file', 'wb_mask'], #func run, wb mask of bet
                        output_names=['mask_file'],
                        function=resample_mask),
                        name='resample_mask')

workflow.connect(bet, 'mask_file', get_fmri_mask, 'wb_mask')
workflow.connect(volreg_raw, 'out_file', get_fmri_mask, 'in_file')

# %% [markdown]
# ### Define input arguments for NORDIC
# - not mandatory, otherwise default values will be initialized for ARG in NIFTI_NORDIC_nipype.m

# %% [raw]
# % OPTIONS
# % ------------------------------------------------------------------------------------------
# %   ARG.DIROUT    VAL=      string        Default is empty
# %   ARG.noise_volume_last   VAL  = num  specifiec volume from the end of the series
# %                                          0 default
# %
# %   ARG.factor_error        val  = num    >1 use higher noisefloor <1 use lower noisefloor
# %                                          1 default
# %
# %   ARG.full_dynamic_range  val = [ 0 1]   0 keep the input scale, output maximizes range.
# %                                            Default 0
# %   ARG.temporal_phase      val = [1 2 3]  1 was default, 3 now in dMRI due tophase errors in some data
# %   ARG.NORDIC              val = [0 1]    1 Default
# %   ARG.MP                  val = [0 1 2]  1 NORDIC gfactor with MP estimation.
# %                                          2 MP without gfactor correction
# %                                          0 default
# %   ARG.kernel_size_gfactor val = [val1 val2 val], defautl is [14 14 1]
# %   ARG.kernel_size_PCA     val = [val1 val2 val], default is val1=val2=val3;
# %                                                  ratio of 11:1 between spatial and temproal voxels
# %   ARG.magnitude_only      val =[] or 1.  Using complex or magntiude only. Default is []
# %                                          Function still needs two inputs but will ignore the second
# %
# %   ARG.save_add_info       val =[0 1];  If it is 1, then an additonal matlab file is being saved with degress removed etc.
# %                                         default is 0
# %   ARG.make_complex_nii    if the field exist, then the phase is being saved in a similar format as the input phase
# %
# %   ARG.phase_slice_average_for_kspace_centering     val = [0 1]
# %                                         if val =0, not used, if val=1 the series average pr slice is first removed
# %                                         default is now 0
# %   ARG.phase_filter_width  val = [1... 10]  Specifiec the width of the smoothing filter for the phase
# %                                         default is now 3
# %
# %   ARG.save_gfactor_map   val = [1 2].  1, saves the RELATIVE gfactor, 2 saves the
# %                                            gfactor and does not complete the NORDIC processing
# %
# %   ARG.write_gzipped_niftis  val = [0, 1]  Output files are written to
# %                                           disk ask compressed *.nii.gz NIfTIs.
# %                                           default is 0 (= false).

# %%
arg_struct = {
    'noise_volume_last': 0,             # specifies volume from the end of the series, default = 0
    'factor_error': 1,                  # >1 use higher noisefloor, <1 use lower noisefloor, default = 1
    'full_dynamic_range': 0,            # 0 keep input scale, output maximises range, default = 0
    'temporal_phase': 1,                # calculate and apply spatial filter to each time-point - better in case of phase-drifts etc., default = 3
    'phase_filter_width': 10,            # specifies the width of the smoothing filter for the phase, default = 3
    'noise_volume_last': 0,             # specifiec volume from the end of the series, default = 0
    'gfactor_patch_overlap' : 6,        # overlap for the patch within which local PCA is ran
    'kernel_size' : [14,14,1],          # also [28, 28, 1]
    'magnitude_only': 1,                # Using complex or magnitude only. Default is []. Function still needs two inputs but will ignore the second
    'save_gfactor_map': 1,              # 1 saves the realtive gfactor, 2 saves the gfactor and does not complete the NORDIC processing
    'save_add_info': 1,                 # save additional information, including the number of components removed
    'save_residual_matlab': 1,          # saves the NORDIC residuals
}

#saves mat in the given directory
mat_file_opt = 'ARG_nordic.mat'
savemat(mat_file_opt, {'ARG': arg_struct}) #needs to be called ARG for it to work in the NIFTI_NORDIC_nipype matlab script

cwd = os.getcwd()

# %% [markdown]
# ### Create Nipype Node with NIFTI_NORDIC Interface

# %%
# Define paths to files and other input arguments
fn_phase_in = fn_magn_in #we chose magnitude only; the function will still need two inputs, but will ignore the second
fn_out = '_NORDIC'
nifti_nordic_script_path = scripts_dir #path where NIFTI_NORDIC_nipype.m is stored
ARG = os.path.join(cwd, mat_file_opt)

# Create the node
nifti_nordic_node = Node(NiftiNordic(), name='nifti_nordic')

# Set the input values
nifti_nordic_node.inputs.fn_magn_in = fn_magn_in
nifti_nordic_node.inputs.fn_phase_in = fn_phase_in
nifti_nordic_node.inputs.fn_out = fn_out
nifti_nordic_node.inputs.additional_path = nifti_nordic_script_path #needs this to add it to the matlab paths
nifti_nordic_node.inputs.ARG = ARG #input is not mandatory

# %% [markdown]
# ### Motion Correciton after Nordic

# %%
# Motion correction AFNI 3dvolreg------------------------------------------------------------------------------
volreg_nordic = Node(afni.Volreg(interp='Fourier', outputtype = 'NIFTI_GZ'), 
                 name='volreg_nordic')

workflow.connect(nifti_nordic_node, 'output_file', volreg_nordic, 'in_file')

# %% [markdown]
# ### Mask functional data (raw and after nordic)

# %%
masker_raw = Node(ApplyMask(), name='masker_raw')
workflow.connect(volreg_raw, 'out_file', masker_raw, 'in_file')
workflow.connect(get_fmri_mask, 'mask_file', masker_raw, 'mask_file')

# %%
masker_nordic = Node(ApplyMask(), name='masker_nordic')
workflow.connect(volreg_nordic, 'out_file', masker_nordic, 'in_file')
workflow.connect(get_fmri_mask, 'mask_file', masker_nordic, 'mask_file')

# %% [markdown]
# ### Node to compute TSNR
# Computes the time-course SNR for a time series
#
# Typically you want to run this on a realigned time-series - in this case, it is not realigned yet.

# %%
tsnr_nordic = Node(TSNR(), name='compute_tsnr_nordic')
workflow.connect(masker_nordic, 'out_file', tsnr_nordic,'in_file')

# %%
tsnr_raw = Node(TSNR(), name='compute_tsnr_raw')
workflow.connect(masker_raw, 'out_file', tsnr_raw,'in_file')

# %% [markdown]
# #### Plot TSNR

# %%
def plot_tsnr(data_path, base_name):
    import numpy as np
    import nibabel as nib
    import matplotlib as mpl
    import matplotlib.pyplot as plt
    import os
    
    data = nib.load(data_path).get_fdata()

    x = data.shape[0] // 2
    y = data.shape[1] // 2
    z = data.shape[2] // 2

    fig, axes = plt.subplots(2, 2) #, gridspec_kw={'width_ratios': [1, 1], 'height_ratios': [1, 0.1]})

    ax = axes[0, 0]
    im = ax.imshow(data[:, :, z], cmap=mpl.cm.hot,vmax=40)
    ax.set_title(f'Axial Slice at z={z}')

    ax = axes[0, 1]
    im = ax.imshow(np.rot90(data[:, y, :]), cmap=mpl.cm.hot,vmax=40)
    ax.set_title(f'Coronal Slice at y={y}')

    ax = axes[1, 0]
    im = ax.imshow(np.rot90(data[x, :, :]), cmap=mpl.cm.hot, vmax=40)
    ax.set_title(f'Sagittal Slice at x={x}')

    # Remove the unused subplot
    fig.delaxes(axes[1, 1])

    cbar_ax = fig.add_axes([0.95, 0.15, 0.02, 0.7])  # [x, y, width, height]
    fig.colorbar(im, cax=cbar_ax)

    fig.set_size_inches(9, 9) #8,8
    #mean_tsnr = np.mean(data[data>0])
    global_tsnr = np.median(data[data > 0])
    

    if base_name.endswith('.gz'):
        basename = os.path.basename(base_name)[0:-7]
    elif base_name.endswith('.nii'):
        basename = os.path.basename(base_name)[0:-4]
    title = 'Global TSNR of  ' + basename + ': ' + str(int(global_tsnr))
    fig.suptitle(title, fontsize=12) 
    
    path_mapflow, _ = os.path.split(os.getcwd())
    path_node, _ = os.path.split(path_mapflow)
    
    plt.savefig(path_node +'/'+ basename) 

#tsrn of denoised data
tsnr_plot_nordic = Node(Function(input_names=['data_path', 'base_name'], 
                                function=plot_tsnr),
                                name='plot_tsnr_nordic')

workflow.connect(tsnr_nordic, 'tsnr_file', tsnr_plot_nordic, 'data_path')
workflow.connect(volreg_nordic, 'out_file', tsnr_plot_nordic, 'base_name')


#tsrn of raw data
tsnr_plot_raw = Node(Function(input_names=['data_path', 'base_name'],
                                function=plot_tsnr),
                                name='plot_tsnr_raw')

workflow.connect(tsnr_raw, 'tsnr_file', tsnr_plot_raw, 'data_path')
workflow.connect(volreg_raw, 'out_file', tsnr_plot_raw, 'base_name')

# %% [markdown]
# ### Datasink Node

# %%
# Create a DataSink node to save the output to a specified location
datasink = Node(DataSink(base_directory=os.path.join(experiment_dir, 'workflow_nordic')),
               name='datasink')


# Connect desired outputs to datasink
#nordic
workflow.connect(nifti_nordic_node, 'output_file', datasink, 'nordic_output') 
workflow.connect(nifti_nordic_node, 'add_info_file', datasink, 'nordic_output.@info_file')
workflow.connect(nifti_nordic_node, 'gfactor_map_file', datasink, 'nordic_output.@gfactor')
workflow.connect(nifti_nordic_node, 'residual_mat_file', datasink, 'nordic_output.@residual')

#tsnr
workflow.connect(tsnr_nordic, 'tsnr_file', datasink, 'tsnr_output.@tsnr_nordic')
workflow.connect(tsnr_raw, 'tsnr_file', datasink, 'tsnr_output.@tsnr_raw')

# %%
# Create output graph
workflow.write_graph(graph2use='colored', format='png', simple_form=True)

# Visualize the graph
from IPython.display import Image
Image(filename=os.path.join(workflow.base_dir, workflow.name, 'graph.png'))
# Out:
# 240829-07:46:48,747 nipype.workflow INFO:
# 	 Generated workflow graph: /mnt/neurodesktop-storage/Analysis/NORDIC/Notebooks/NORDIC_output/workflow_nordic/graph.png (graph2use=colored, simple_form=True).

# %%
workflow.write_graph(graph2use='flat', format='png', simple_form=True)

Image(filename=os.path.join(workflow.base_dir, workflow.name, 'graph_detailed.png'))
# Out:
# 240829-07:46:49,143 nipype.workflow INFO:
# 	 Generated workflow graph: /mnt/neurodesktop-storage/Analysis/NORDIC/Notebooks/NORDIC_output/workflow_nordic/graph.png (graph2use=flat, simple_form=True).

# %%
# Run the workflow
workflow.run('MultiProc', plugin_args={'n_procs':16})
# Out:
# 240829-07:46:51,988 nipype.workflow INFO:
# 	 Workflow workflow_nordic settings: ['check', 'execution', 'logging', 'monitoring']
# 240829-07:46:52,23 nipype.workflow INFO:
# 	 Running in parallel.
# 240829-07:46:52,34 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 3 jobs ready. Free memory (GB): 219.48/219.48, Free processors: 16/16.
# 240829-07:46:52,115 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "workflow_nordic.bet".
# 240829-07:46:52,336 nipype.workflow INFO:
# 	 [Job 1] Cached (workflow_nordic.volreg_raw).
# 240829-07:46:52,338 nipype.workflow INFO:
# 	 [Node] Setting-up "workflow_nordic.bet" in "/mnt/neurodesktop-storage/Analysis/NORDIC/Notebooks/NORDIC_output/workflow_nordic/bet".
# 240829-07:46:52,356 nipype.workflow INFO:
# 	 [Job 2] Cached (workflow_nordic.nifti_nordic).
# 240829-07:46:52,356 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "workflow_nordic.bet".
# 240829-07:46:52,362 nipype.workflow INFO:
# 	 [Node] Executing "bet" <nipype.interfaces.fsl.preprocess.BET>
# 240829-07:46:54,31 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 219.28/219.48, Free processors: 15/16.
#                      Currently running:
#                        * workflow_nordic.bet
# 240829-07:46:54,311 nipype.workflow INFO:
# 	 [Job 4] Cached (workflow_nordic.volreg_nordic).
# 240829-07:46:56,31 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 219.28/219.48, Free processors: 15/16.
#                      Currently running:
#                        * workflow_nordic.bet
# 240829-07:46:57,230 nipype.workflow INFO:
# 	 [Node] Finished "bet", elapsed time 4.865357s.
# 240829-07:46:58,30 nipype.workflow INFO:
# 	 [Job 0] Completed (workflow_nordic.bet).
# 240829-07:46:58,32 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 219.48/219.48, Free processors: 16/16.
# 240829-07:46:58,114 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "workflow_nordic.resample_mask".
# 240829-07:46:58,117 nipype.workflow INFO:
# 	 [Node] Setting-up "workflow_nordic.resample_mask" in "/mnt/neurodesktop-storage/Analysis/NORDIC/Notebooks/NORDIC_output/workflow_nordic/resample_mask".
# 240829-07:46:58,121 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "workflow_nordic.resample_mask".
# 240829-07:46:58,126 nipype.workflow INFO:
# 	 [Node] Executing "resample_mask" <nipype.interfaces.utility.wrappers.Function>
# 240829-07:47:00,31 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 219.28/219.48, Free processors: 15/16.
#                      Currently running:
#                        * workflow_nordic.resample_mask
# 240829-07:47:02,728 nipype.workflow INFO:
# 	 [Node] Finished "resample_mask", elapsed time 4.599345s.
# 240829-07:47:04,31 nipype.workflow INFO:
# 	 [Job 3] Completed (workflow_nordic.resample_mask).
# 240829-07:47:04,33 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 219.48/219.48, Free processors: 16/16.
# 240829-07:47:04,112 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "workflow_nordic.masker_raw".
# 240829-07:47:04,115 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "workflow_nordic.masker_nordic".
# 240829-07:47:04,117 nipype.workflow INFO:
# 	 [Node] Setting-up "workflow_nordic.masker_raw" in "/mnt/neurodesktop-storage/Analysis/NORDIC/Notebooks/NORDIC_output/workflow_nordic/masker_raw".
# 240829-07:47:04,121 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "workflow_nordic.masker_raw".
# 240829-07:47:04,119 nipype.workflow INFO:
# 	 [Node] Setting-up "workflow_nordic.masker_nordic" in "/mnt/neurodesktop-storage/Analysis/NORDIC/Notebooks/NORDIC_output/workflow_nordic/masker_nordic".
# 240829-07:47:04,123 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "workflow_nordic.masker_nordic".
# 240829-07:47:04,178 nipype.workflow INFO:
# 	 [Node] Executing "masker_raw" <nipype.interfaces.fsl.maths.ApplyMask>
# 240829-07:47:04,184 nipype.workflow INFO:
# 	 [Node] Executing "masker_nordic" <nipype.interfaces.fsl.maths.ApplyMask>
# 240829-07:47:06,31 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 219.08/219.48, Free processors: 14/16.
#                      Currently running:
#                        * workflow_nordic.masker_nordic
#                        * workflow_nordic.masker_raw
# 240829-07:47:17,556 nipype.workflow INFO:
# 	 [Node] Finished "masker_nordic", elapsed time 13.357135s.
# 240829-07:47:18,32 nipype.workflow INFO:
# 	 [Job 6] Completed (workflow_nordic.masker_nordic).
# 240829-07:47:18,35 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 219.28/219.48, Free processors: 15/16.
#                      Currently running:
#                        * workflow_nordic.masker_raw
# 240829-07:47:18,127 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "workflow_nordic.compute_tsnr_nordic".
# 240829-07:47:18,131 nipype.workflow INFO:
# 	 [Node] Setting-up "workflow_nordic.compute_tsnr_nordic" in "/mnt/neurodesktop-storage/Analysis/NORDIC/Notebooks/NORDIC_output/workflow_nordic/compute_tsnr_nordic".
# 240829-07:47:18,135 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "workflow_nordic.compute_tsnr_nordic".
# 240829-07:47:18,140 nipype.workflow INFO:
# 	 [Node] Executing "compute_tsnr_nordic" <nipype.algorithms.confounds.TSNR>
# 240829-07:47:20,33 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 219.08/219.48, Free processors: 14/16.
#                      Currently running:
#                        * workflow_nordic.compute_tsnr_nordic
#                        * workflow_nordic.masker_raw
# 240829-07:47:24,187 nipype.workflow INFO:
# 	 [Node] Finished "compute_tsnr_nordic", elapsed time 6.04392s.
# 240829-07:47:24,482 nipype.workflow INFO:
# 	 [Node] Finished "masker_raw", elapsed time 20.300734s.
# 240829-07:47:26,33 nipype.workflow INFO:
# 	 [Job 5] Completed (workflow_nordic.masker_raw).
# 240829-07:47:26,34 nipype.workflow INFO:
# 	 [Job 8] Completed (workflow_nordic.compute_tsnr_nordic).
# 240829-07:47:26,36 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 219.48/219.48, Free processors: 16/16.
# 240829-07:47:26,117 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "workflow_nordic.compute_tsnr_raw".
# 240829-07:47:26,121 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "workflow_nordic.plot_tsnr_nordic".
# 240829-07:47:26,121 nipype.workflow INFO:
# 	 [Node] Setting-up "workflow_nordic.compute_tsnr_raw" in "/mnt/neurodesktop-storage/Analysis/NORDIC/Notebooks/NORDIC_output/workflow_nordic/compute_tsnr_raw".
# 240829-07:47:26,126 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "workflow_nordic.compute_tsnr_raw".
# 240829-07:47:26,124 nipype.workflow INFO:
# 	 [Node] Setting-up "workflow_nordic.plot_tsnr_nordic" in "/mnt/neurodesktop-storage/Analysis/NORDIC/Notebooks/NORDIC_output/workflow_nordic/plot_tsnr_nordic".
# 240829-07:47:26,129 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "workflow_nordic.plot_tsnr_nordic".
# 240829-07:47:26,131 nipype.workflow INFO:
# 	 [Node] Executing "compute_tsnr_raw" <nipype.algorithms.confounds.TSNR>
# 240829-07:47:26,134 nipype.workflow INFO:
# 	 [Node] Executing "plot_tsnr_nordic" <nipype.interfaces.utility.wrappers.Function>
# 240829-07:47:26,940 nipype.workflow INFO:
# 	 [Node] Finished "plot_tsnr_nordic", elapsed time 0.802315s.
# 240829-07:47:28,33 nipype.workflow INFO:
# 	 [Job 10] Completed (workflow_nordic.plot_tsnr_nordic).
# 240829-07:47:28,35 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 219.28/219.48, Free processors: 15/16.
#                      Currently running:
#                        * workflow_nordic.compute_tsnr_raw
# 240829-07:47:28,854 nipype.workflow INFO:
# 	 [Node] Finished "compute_tsnr_raw", elapsed time 2.7201589999999998s.
# 240829-07:47:30,33 nipype.workflow INFO:
# 	 [Job 7] Completed (workflow_nordic.compute_tsnr_raw).
# 240829-07:47:30,35 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 219.48/219.48, Free processors: 16/16.
# 240829-07:47:30,117 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "workflow_nordic.plot_tsnr_raw".
# 240829-07:47:30,120 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "workflow_nordic.datasink".
# 240829-07:47:30,119 nipype.workflow INFO:
# 	 [Node] Setting-up "workflow_nordic.plot_tsnr_raw" in "/mnt/neurodesktop-storage/Analysis/NORDIC/Notebooks/NORDIC_output/workflow_nordic/plot_tsnr_raw".
# 240829-07:47:30,125 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "workflow_nordic.plot_tsnr_raw".
# 240829-07:47:30,124 nipype.workflow INFO:
# 	 [Node] Setting-up "workflow_nordic.datasink" in "/mnt/neurodesktop-storage/Analysis/NORDIC/Notebooks/NORDIC_output/workflow_nordic/datasink".
# 240829-07:47:30,128 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "workflow_nordic.datasink".
# 240829-07:47:30,129 nipype.workflow INFO:
# 	 [Node] Executing "plot_tsnr_raw" <nipype.interfaces.utility.wrappers.Function>
# 240829-07:47:30,136 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 240829-07:47:30,146 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.006477s.
# 240829-07:47:30,883 nipype.workflow INFO:
# 	 [Node] Finished "plot_tsnr_raw", elapsed time 0.747779s.
# 240829-07:47:32,33 nipype.workflow INFO:
# 	 [Job 9] Completed (workflow_nordic.plot_tsnr_raw).
# 240829-07:47:32,35 nipype.workflow INFO:
# 	 [Job 11] Completed (workflow_nordic.datasink).
# 240829-07:47:32,36 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 219.48/219.48, Free processors: 16/16.

# %% [markdown]
# ### Check output

# %%
# !cd NORDIC_output && tree -L 4
# Out:
# .
# ├── sub-001_ses-01_task-HalfFovNoTask_run-003_bold_NORDIC_volreg.png
# ├── sub-001_ses-01_task-HalfFovNoTask_run-003_bold_volreg.png
# └── workflow_nordic
#     ├── bet
#     │   ├── _0xb4d42c49e72b9acf40a654682f21856f.json
#     │   ├── _inputs.pklz
#     │   ├── _node.pklz
#     │   ├── _report
#     │   │   └── report.rst
#     │   ├── command.txt
#     │   ├── result_bet.pklz
#     │   └── sub-001_ses-01_acq-MPRAGE_run-001_T1w_brain_mask.nii.gz
#     ├── compute_tsnr_nordic
#     │   ├── _0xdea4f51802b4eb5b2756291f802751c5.json
#     │   ├── _inputs.pklz
#     │   ├── _node.pklz
#     │   ├── _report
#     │   │   └── report.rst
#     │   ├── result_compute_tsnr_nordic.pklz
#     │   └── tsnr.nii.gz
#     ├── compute_tsnr_raw
#     │   ├── _0x9b013fefbcfa9fd62ff8109c93e675b5.json
#     │   ├── _inputs.pklz
#     │   ├── _node.pklz
#     │   ├── _report
#     │   │   └── report.rst
#     │   ├── result_compute_tsnr_raw.pklz
#     │   └── tsnr.nii.gz
#     ├── d3.js
#     ├── datasink
#     │   ├── _0xc34abce179e903410e753b95b4566838.json
#     │   ├── _inputs.pklz
#     │   ├── _node.pklz
#     │   ├── _report
#     │   │   └── report.rst
#     │   └── result_datasink.pklz
#     ├── graph.dot
#     ├── graph.json
#     ├── graph.png
#     ├── graph1.json
#     ├── graph_detailed.dot
#     ├── graph_detailed.png
#     ├── index.html
#     ├── masker_nordic
#     │   ├── _0x4153f1141b0b12b08a9c2d2f81380097.json
#     │   ├── _inputs.pklz
#     │   ├── _node.pklz
#     │   ├── _report
#     │   │   └── report.rst
#     │   ├── command.txt
#     │   ├── result_masker_nordic.pklz
#     │   └── sub-001_ses-01_task-HalfFovNoTask_run-003_bold_NORDIC_volreg_masked.nii.gz
#     ├── masker_raw
#     │   ├── _0x6b76105a1249b3369db7995d2eea4bf7.json
#     │   ├── _inputs.pklz
#     │   ├── _node.pklz
#     │   ├── _report
#     │   │   └── report.rst
#     │   ├── command.txt
#     │   ├── result_masker_raw.pklz
#     │   └── sub-001_ses-01_task-HalfFovNoTask_run-003_bold_volreg_masked.nii.gz
#     ├── nifti_nordic
#     │   ├── RESIDUALsub-001_ses-01_task-HalfFovNoTask_run-003_bold_NORDIC.mat
#     │   ├── _0xb54a7903df747afc41270b873cb0ba9b.json
#     │   ├── _inputs.pklz
#     │   ├── _node.pklz
#     │   ├── _report
#     │   │   └── report.rst
#     │   ├── gfactor_sub-001_ses-01_task-HalfFovNoTask_run-003_bold_NORDIC.nii
#     │   ├── result_nifti_nordic.pklz
#     │   ├── sub-001_ses-01_task-HalfFovNoTask_run-003_bold_NORDIC.mat
#     │   └── sub-001_ses-01_task-HalfFovNoTask_run-003_bold_NORDIC.nii
#     ├── nordic_output
#     │   ├── RESIDUALsub-001_ses-01_task-HalfFovNoTask_run-003_bold_NORDIC.mat
#     │   ├── gfactor_sub-001_ses-01_task-HalfFovNoTask_run-003_bold_NORDIC.nii
#     │   ├── sub-001_ses-01_task-HalfFovNoTask_run-003_bold_NORDIC.mat
#     │   └── sub-001_ses-01_task-HalfFovNoTask_run-003_bold_NORDIC.nii
#     ├── plot_tsnr_nordic
#     │   ├── _0x75835623dad019ca6080f3e855fdd018.json
#     │   ├── _inputs.pklz
#     │   ├── _node.pklz
#     │   ├── _report
#     │   │   └── report.rst
#     │   └── result_plot_tsnr_nordic.pklz
#     ├── plot_tsnr_raw
#     │   ├── _0xf6417dfbbf8f3af3928a493efebdd43a.json
#     │   ├── _inputs.pklz
#     │   ├── _node.pklz
#     │   ├── _report
#     │   │   └── report.rst
#     │   └── result_plot_tsnr_raw.pklz
#     ├── resample_mask
#     │   ├── _0x2f974144f2d9b566d91589d52a889ead.json
#     │   ├── _inputs.pklz
#     │   ├── _node.pklz
#     │   ├── _report
#     │   │   └── report.rst
#     │   ├── result_resample_mask.pklz
#     │   └── sub-001_ses-01_task-HalfFovNoTask_run-003_bold_volreg_func_mask.nii.gz
#     ├── robex
#     │   ├── _inputs.pklz
#     │   ├── _node.pklz
#     │   ├── _report
#     │   │   └── report.rst
#     │   └── result_robex.pklz
#     ├── tsnr_output
#     │   └── tsnr.nii.gz
#     ├── volreg_nordic
#     │   ├── _0x8e86ce02bba65176a6d7c44dd3fa9f39.json
#     │   ├── _inputs.pklz
#     │   ├── _node.pklz
#     │   ├── _report
#     │   │   └── report.rst
#     │   ├── command.txt
#     │   ├── result_volreg_nordic.pklz
#     │   └── sub-001_ses-01_task-HalfFovNoTask_run-003_bold_NORDIC_volreg.nii.gz
#     └── volreg_raw
#         ├── _0x7f7805951accec66767d7f2c98097fd5.json
#         ├── _inputs.pklz
#         ├── _node.pklz
#         ├── _report
#         │   └── report.rst
#         ├── command.txt
#         ├── result_volreg_raw.pklz
#         └── sub-001_ses-01_task-HalfFovNoTask_run-003_bold_volreg.nii.gz
#
# 29 directories, 96 files

# %% [markdown]
# ### Plot TSNR maps and the global TSNR (median) to check the effect of NORDIC

# %%
tsnr_img_nordic = os.path.join(experiment_dir, 'sub-001_ses-01_task-HalfFovNoTask_run-003_bold_NORDIC_volreg.png')
tsnr_img_raw = os.path.join(experiment_dir, 'sub-001_ses-01_task-HalfFovNoTask_run-003_bold_volreg.png')

# %%
from IPython.display import Image
Image(filename=tsnr_img_nordic)

# %%
# Display a local image
Image(filename=tsnr_img_raw)
